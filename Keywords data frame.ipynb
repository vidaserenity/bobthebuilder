# %% [markdown]
# # Reading the keywords.csv as a dataframe and then plan to recommend the 1000+ keywords based on type of resume

# %%
import pandas as pd
import numpy as np

# %%
keywords = pd.read_csv("keywords.csv")

# %%
keywords
# Out:
#               Administration                  Childcare  \
# 0           Accounts payable           Active listening
# 1        Account receivables      Activity coordination
# 2   Administrative processes          Activity planning
# 3                    Billing            Age-appropriate
# 4                Bookkeeping                 Age groups
# 5                  Budgeting        Attention to detail
# 6                Calendaring                   Behavior
# 7      Client communications                    Caring
# 8           Clerical support           Child psychology
# 9              Communication              Child welfare
# 10                Compliance       Childcare experience
# 11       Conflict resolution         Childcare provider
# 12          Contract support          Close supervision
# 13          Customer service              Communication
# 14                Data entry                    Comfort
# 15       Database management                 Compassion
# ...
